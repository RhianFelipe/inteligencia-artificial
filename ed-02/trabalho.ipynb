# %%
lista_fat = []
def fatorial(n):
    fat = 1
    i = 1
    while i <= n:
        fat = fat*i
        lista_fat.append(fat)
        print(f"O valor de {i}! eh = {lista_fat}") 
        i = i + 1
        
#-----
fatorial(10)
lista_fat.sort(reverse=True)
print(f'Lista Fatorial decrescente:{lista_fat}')
# Out:
# O valor de 1! eh = [1]
# O valor de 2! eh = [1, 2]
# O valor de 3! eh = [1, 2, 6]
# O valor de 4! eh = [1, 2, 6, 24]
# O valor de 5! eh = [1, 2, 6, 24, 120]
# O valor de 6! eh = [1, 2, 6, 24, 120, 720]
# O valor de 7! eh = [1, 2, 6, 24, 120, 720, 5040]
# O valor de 8! eh = [1, 2, 6, 24, 120, 720, 5040, 40320]
# O valor de 9! eh = [1, 2, 6, 24, 120, 720, 5040, 40320, 362880]
# O valor de 10! eh = [1, 2, 6, 24, 120, 720, 5040, 40320, 362880, 3628800]
# Lista Fatorial decrescente:[3628800, 362880, 40320, 5040, 720, 120, 24, 6, 2, 1]

# %%
troco = 0
n50=0
n20=0
n10=0
n5=0
n2=0
n1=0
troco = float(input("Entre com o valor do Saque: "))
while troco > 1:
    if(troco == 50):
      n50 = n50 + 1
      troco = troco - 50
    elif(troco == 20):
      n20 = n20 + 1
      troco = troco - 20
    elif(troco == 10):
      n10 = n10 + 1
      troco = troco - 10
    elif(troco == 5):
      n5 = n5 + 1
      troco = troco - 5
    elif(troco == 2):
      n2 = n2 + 1
      troco = troco - 2


print(f"{n50} nota de 50\n{n20} nota(s) de 20\n{n10} nota(s) de 10\n{n5} nota(s) de 5\n{n2} moeda(s) de 2\n{n1} moeda de 1");
# Out:
# Entre com o valor do Saque: 50
# 1 nota de 50
# 0 nota(s) de 20
# 0 nota(s) de 10
# 0 nota(s) de 5
# 0 moeda(s) de 2
# 0 moeda de 1

# %% [markdown]
# texto em itálico
